# %%
# # Geração de Dataset com Métricas do cAdvisor
# Notebook para coletar todas as métricas disponíveis do cAdvisor via Prometheus

# ## 1. Instalação de Dependências

# !pip install requests pandas

# ## 2. Imports

import requests
import pandas as pd
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# ## 3. Configuração

# **CONFIGURE AQUI:**
PROMETHEUS_URL = 'http://localhost:9090'  # URL do seu Prometheus
POD_FILTER = 'memory-stress-.*'  # Filtro de pods (ou None para todos)
NAMESPACE = None  # Namespace específico (ou None para todos)
DURATION_MINUTES = 30  # Duração da coleta em minutos
STEP = '30s'  # Intervalo entre pontos

# ## 4. Função de Coleta

def collect_cadvisor_metrics(prometheus_url, duration_minutes=30, step='30s', 
                             pod_filter=None, namespace=None):
    """
    Coleta todas as métricas do cAdvisor disponíveis no Prometheus
    
    Args:
        prometheus_url: URL do Prometheus
        duration_minutes: Duração da coleta em minutos
        step: Intervalo entre pontos
        pod_filter: Regex para filtrar pods
        namespace: Namespace específico
    
    Returns:
        DataFrame com todas as métricas
    """
    
    # Calcula timestamps
    end_time = datetime.now()
    start_time = end_time - timedelta(minutes=duration_minutes)
    start_ts = int(start_time.timestamp())
    end_ts = int(end_time.timestamp())
    
    api_url = f"{prometheus_url.rstrip('/')}/api/v1"
    
    # Lista completa de métricas do cAdvisor
    cadvisor_metrics = [
        # CPU
        'container_cpu_usage_seconds_total',
        'container_cpu_user_seconds_total',
        'container_cpu_system_seconds_total',
        'container_cpu_cfs_periods_total',
        'container_cpu_cfs_throttled_periods_total',
        'container_cpu_cfs_throttled_seconds_total',
        
        # Memória
        'container_memory_usage_bytes',
        'container_memory_working_set_bytes',
        'container_memory_rss',
        'container_memory_cache',
        'container_memory_swap',
        'container_memory_mapped_file',
        'container_memory_max_usage_bytes',
        'container_memory_failcnt',
        'container_memory_failures_total',
        
        # Especificações e Limites
        'container_spec_memory_limit_bytes',
        'container_spec_memory_swap_limit_bytes',
        'container_spec_memory_reservation_limit_bytes',
        'container_spec_cpu_quota',
        'container_spec_cpu_period',
        'container_spec_cpu_shares',
        
        # Rede
        'container_network_receive_bytes_total',
        'container_network_receive_packets_total',
        'container_network_receive_packets_dropped_total',
        'container_network_receive_errors_total',
        'container_network_transmit_bytes_total',
        'container_network_transmit_packets_total',
        'container_network_transmit_packets_dropped_total',
        'container_network_transmit_errors_total',
        'container_network_tcp_usage_total',
        'container_network_udp_usage_total',
        
        # Disco/Filesystem
        'container_fs_usage_bytes',
        'container_fs_limit_bytes',
        'container_fs_reads_bytes_total',
        'container_fs_reads_total',
        'container_fs_read_seconds_total',
        'container_fs_writes_bytes_total',
        'container_fs_writes_total',
        'container_fs_write_seconds_total',
        'container_fs_io_time_seconds_total',
        'container_fs_io_time_weighted_seconds_total',
        'container_fs_reads_merged_total',
        'container_fs_writes_merged_total',
        'container_fs_sector_reads_total',
        'container_fs_sector_writes_total',
        'container_fs_inodes_free',
        'container_fs_inodes_total',
        
        # Processos e Tarefas
        'container_processes',
        'container_threads',
        'container_threads_max',
        'container_file_descriptors',
        'container_sockets',
        'container_tasks_state',
        
        # OOM
        'container_oom_events_total',
        
        # Outras
        'container_start_time_seconds',
        'container_last_seen',
    ]
    
    all_data = []
    total_metrics = len(cadvisor_metrics)
    
    print(f"🔍 Coletando {total_metrics} métricas do cAdvisor...")
    print(f"📅 Período: {start_time.strftime('%Y-%m-%d %H:%M:%S')} até {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"⏱️  Step: {step}\n")
    
    for idx, metric in enumerate(cadvisor_metrics, 1):
        # Monta filtros
        filters = []
        if pod_filter:
            filters.append(f'pod=~"{pod_filter}"')
        if namespace:
            filters.append(f'namespace="{namespace}"')
        
        # Monta query
        if filters:
            query = f'{metric}{{{",".join(filters)}}}'
        else:
            query = metric
        
        print(f"[{idx}/{total_metrics}] {metric}...", end=' ')
        
        try:
            # Faz requisição
            response = requests.get(
                f"{api_url}/query_range",
                params={
                    'query': query,
                    'start': start_ts,
                    'end': end_ts,
                    'step': step
                },
                timeout=60
            )
            response.raise_for_status()
            result = response.json()
            
            # Processa resultados
            if result['status'] == 'success' and result['data']['result']:
                count = 0
                for item in result['data']['result']:
                    for timestamp, value in item['values']:
                        # Cria registro
                        record = {
                            'timestamp': datetime.fromtimestamp(timestamp),
                            'metric_name': metric,
                            'value': float(value) if value != 'NaN' else None,
                        }
                        
                        # Adiciona todas as labels
                        for label, label_value in item['metric'].items():
                            record[label] = label_value
                        
                        all_data.append(record)
                        count += 1
                
                print(f"✅ {count} registros")
            else:
                print("⚠️  Sem dados")
        
        except Exception as e:
            print(f"❌ Erro: {str(e)[:50]}")
    
    # Cria DataFrame
    if all_data:
        df = pd.DataFrame(all_data)
        print(f"\n✨ Dataset gerado com sucesso!")
        print(f"   Total de registros: {len(df):,}")
        print(f"   Métricas coletadas: {df['metric_name'].nunique()}")
        return df
    else:
        print("\n⚠️  Nenhum dado foi coletado!")
        return pd.DataFrame()

# ## 5. Coleta dos Dados

print("="*70)
print("INICIANDO COLETA DE MÉTRICAS DO CADVISOR")
print("="*70 + "\n")

df = collect_cadvisor_metrics(
    prometheus_url=PROMETHEUS_URL,
    duration_minutes=DURATION_MINUTES,
    step=STEP,
    pod_filter=POD_FILTER,
    namespace=NAMESPACE
)

# ## 6. Informações do Dataset

if not df.empty:
    print("\n" + "="*70)
    print("INFORMAÇÕES DO DATASET")
    print("="*70)
    
    print(f"\n📊 Shape: {df.shape}")
    print(f"📋 Colunas: {list(df.columns)}")
    print(f"\n⏰ Período dos dados:")
    print(f"   Início: {df['timestamp'].min()}")
    print(f"   Fim: {df['timestamp'].max()}")
    
    print(f"\n📈 Métricas coletadas ({df['metric_name'].nunique()}):")
    metrics_count = df.groupby('metric_name').size().sort_values(ascending=False)
    for metric, count in metrics_count.items():
        print(f"   • {metric}: {count:,} registros")
    
    if 'pod' in df.columns:
        print(f"\n🎯 Pods monitorados ({df['pod'].nunique()}):")
        for pod in sorted(df['pod'].unique()):
            pod_metrics = df[df['pod'] == pod]['metric_name'].nunique()
            pod_records = len(df[df['pod'] == pod])
            print(f"   • {pod}: {pod_metrics} métricas, {pod_records:,} registros")
    
    if 'namespace' in df.columns:
        print(f"\n📦 Namespaces: {df['namespace'].nunique()}")
        for ns in sorted(df['namespace'].unique()):
            print(f"   • {ns}")
    
    print("\n📋 Primeiras linhas do dataset:")
    display(df.head(10))
    
    print("\n📊 Tipos de dados:")
    display(df.dtypes)
    
    print("\n📈 Estatísticas dos valores:")
    display(df['value'].describe())

# ## 7. Salvar Dataset

if not df.empty:
    # CSV
    csv_file = 'cadvisor_metrics_dataset.csv'
    df.to_csv(csv_file, index=False)
    print(f"\n✅ Dataset salvo em CSV: {csv_file}")
    
    # Parquet (mais eficiente)
    parquet_file = 'cadvisor_metrics_dataset.parquet'
    df.to_parquet(parquet_file, index=False)
    print(f"✅ Dataset salvo em Parquet: {parquet_file}")
    
    # Excel (opcional - pode ser lento para datasets grandes)
    if len(df) < 100000:  # Apenas se não for muito grande
        excel_file = 'cadvisor_metrics_dataset.xlsx'
        df.to_excel(excel_file, index=False)
        print(f"✅ Dataset salvo em Excel: {excel_file}")
    
    print(f"\n📦 Tamanho dos arquivos:")
    import os
    print(f"   • CSV: {os.path.getsize(csv_file) / 1024 / 1024:.2f} MB")
    print(f"   • Parquet: {os.path.getsize(parquet_file) / 1024 / 1024:.2f} MB")

print("\n" + "="*70)
print("✨ COLETA FINALIZADA COM SUCESSO!")
print("="*70)
# Out:
# ======================================================================
# INICIANDO COLETA DE MÉTRICAS DO CADVISOR
# ======================================================================
#
# 🔍 Coletando 56 métricas do cAdvisor...
# 📅 Período: 2025-10-02 07:47:51 até 2025-10-02 08:17:51
# ⏱️  Step: 30s
#
# [1/56] container_cpu_usage_seconds_total... ✅ 212 registros
# [2/56] container_cpu_user_seconds_total... ⚠️  Sem dados
# [3/56] container_cpu_system_seconds_total... ⚠️  Sem dados
# [4/56] container_cpu_cfs_periods_total... ✅ 151 registros
# [5/56] container_cpu_cfs_throttled_periods_total... ✅ 151 registros
# [6/56] container_cpu_cfs_throttled_seconds_total... ⚠️  Sem dados
# [7/56] container_memory_usage_bytes... ✅ 212 registros
# [8/56] container_memory_working_set_bytes... ✅ 212 registros
# [9/56] container_memory_rss... ✅ 212 registros
# [10/56] container_memory_cache... ✅ 212 registros
# [11/56] container_memory_swap... ⚠️  Sem dados
# [12/56] container_memory_mapped_file... ⚠️  Sem dados
# [13/56] container_memory_max_usage_bytes... ✅ 212 registros
# [14/56] container_memory_failcnt... ✅ 212 registros
# [15/56] container_memory_failures_total... ✅ 424 registros
# [16/56] container_spec_memory_limit_bytes... ⚠️  Sem dados
# [17/56] container_spec_memory_swap_limit_bytes... ⚠️  Sem dados
# [18/56] container_spec_memory_reservation_limit_bytes... ⚠️  Sem dados
# [19/56] container_spec_cpu_quota... ⚠️  Sem dados
# [20/56] container_spec_cpu_period... ⚠️  Sem dados
# [21/56] container_spec_cpu_shares... ⚠️  Sem dados
# [22/56] container_network_receive_bytes_total... ✅ 61 registros
# [23/56] container_network_receive_packets_total... ✅ 61 registros
# [24/56] container_network_receive_packets_dropped_total... ✅ 61 registros
# [25/56] container_network_receive_errors_total... ✅ 61 registros
# [26/56] container_network_transmit_bytes_total... ✅ 61 registros
# [27/56] container_network_transmit_packets_total... ✅ 61 registros
# [28/56] container_network_transmit_packets_dropped_total... ✅ 61 registros
# [29/56] container_network_transmit_errors_total... ✅ 61 registros
# [30/56] container_network_tcp_usage_total... ⚠️  Sem dados
# [31/56] container_network_udp_usage_total... ⚠️  Sem dados
# [32/56] container_fs_usage_bytes... ⚠️  Sem dados
# [33/56] container_fs_limit_bytes... ⚠️  Sem dados
# [34/56] container_fs_reads_bytes_total... ✅ 300 registros
# [35/56] container_fs_reads_total... ✅ 300 registros
# [36/56] container_fs_read_seconds_total... ⚠️  Sem dados
# [37/56] container_fs_writes_bytes_total... ✅ 300 registros
# [38/56] container_fs_writes_total... ✅ 300 registros
# [39/56] container_fs_write_seconds_total... ⚠️  Sem dados
# [40/56] container_fs_io_time_seconds_total... ⚠️  Sem dados
# [41/56] container_fs_io_time_weighted_seconds_total... ⚠️  Sem dados
# [42/56] container_fs_reads_merged_total... ⚠️  Sem dados
# [43/56] container_fs_writes_merged_total... ⚠️  Sem dados
# [44/56] container_fs_sector_reads_total... ⚠️  Sem dados
# [45/56] container_fs_sector_writes_total... ⚠️  Sem dados
# [46/56] container_fs_inodes_free... ⚠️  Sem dados
# [47/56] container_fs_inodes_total... ⚠️  Sem dados
# [48/56] container_processes... ✅ 212 registros
# [49/56] container_threads... ✅ 212 registros
# [50/56] container_threads_max... ⚠️  Sem dados
# [51/56] container_file_descriptors... ⚠️  Sem dados
# [52/56] container_sockets... ✅ 212 registros
# [53/56] container_tasks_state... ⚠️  Sem dados
# [54/56] container_oom_events_total... ✅ 212 registros
# [55/56] container_start_time_seconds... ✅ 183 registros
# [56/56] container_last_seen... ✅ 212 registros
#
# ✨ Dataset gerado com sucesso!
#    Total de registros: 5,141
#    Métricas coletadas: 28
#
# ======================================================================
# INFORMAÇÕES DO DATASET
# ======================================================================
#
# 📊 Shape: (5141, 21)
# 📋 Colunas: ['timestamp', 'metric_name', 'value', '__name__', 'container', 'cpu', 'endpoint', 'id', 'image', 'instance', 'job', 'metrics_path', 'name', 'namespace', 'node', 'pod', 'service', 'failure_type', 'scope', 'interface', 'device']
#
# ⏰ Período dos dados:
#    Início: 2025-10-02 07:47:51
#    Fim: 2025-10-02 08:17:51
#
# 📈 Métricas coletadas (28):
#    • container_memory_failures_total: 424 registros
#    • container_fs_reads_bytes_total: 300 registros
#    • container_fs_reads_total: 300 registros
#    • container_fs_writes_bytes_total: 300 registros
#    • container_fs_writes_total: 300 registros
#    • container_memory_working_set_bytes: 212 registros
#    • container_memory_rss: 212 registros
#    • container_sockets: 212 registros
#    • container_processes: 212 registros
#    • container_oom_events_total: 212 registros
#    • container_memory_usage_bytes: 212 registros
#    • container_threads: 212 registros
#    • container_memory_max_usage_bytes: 212 registros
#    • container_memory_failcnt: 212 registros
#    • container_memory_cache: 212 registros
#    • container_last_seen: 212 registros
#    • container_cpu_usage_seconds_total: 212 registros
#    • container_start_time_seconds: 183 registros
#    • container_cpu_cfs_throttled_periods_total: 151 registros
#    • container_cpu_cfs_periods_total: 151 registros
#    • container_network_receive_bytes_total: 61 registros
#    • container_network_receive_errors_total: 61 registros
#    • container_network_receive_packets_dropped_total: 61 registros
#    • container_network_receive_packets_total: 61 registros
#    • container_network_transmit_bytes_total: 61 registros
#    • container_network_transmit_errors_total: 61 registros
#    • container_network_transmit_packets_dropped_total: 61 registros
#    • container_network_transmit_packets_total: 61 registros
#
# 🎯 Pods monitorados (1):
#    • memory-stress-app-664c7bc4ff-ptfl6: 28 métricas, 5,141 registros
#
# 📦 Namespaces: 1
#    • memory-stress-test
#
# 📋 Primeiras linhas do dataset:
#             timestamp                        metric_name     value  \
# 0 2025-10-02 07:47:51  container_cpu_usage_seconds_total  2.102480
# 1 2025-10-02 07:48:21  container_cpu_usage_seconds_total  2.386242
# 2 2025-10-02 07:48:51  container_cpu_usage_seconds_total  2.916546
# 3 2025-10-02 07:49:21  container_cpu_usage_seconds_total  3.438816
# 4 2025-10-02 07:49:51  container_cpu_usage_seconds_total  3.719793
# 5 2025-10-02 07:50:21  container_cpu_usage_seconds_total  4.149523
# 6 2025-10-02 07:50:51  container_cpu_usage_seconds_total  4.378999
# 7 2025-10-02 07:51:21  container_cpu_usage_seconds_total  4.597126
# 8 2025-10-02 07:51:51  container_cpu_usage_seconds_total  5.027980
# 9 2025-10-02 07:52:21  container_cpu_usage_seconds_total  5.456284
#
#                             __name__      container    cpu       endpoint  \
# 0  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 1  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 2  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 3  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 4  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 5  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 6  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 7  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 8  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
# 9  container_cpu_usage_seconds_total  memory-stress  total  https-metrics
#
#                                                   id  \
# 0  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 1  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 2  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 3  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 4  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 5  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 6  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 7  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 8  /kubepods/burstable/podc90feebe-478d-40e3-a037...
# 9  /kubepods/burstable/podc90feebe-478d-40e3-a037...
#
#                                     image               instance      job  \
# 0  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 1  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 2  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 3  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 4  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 5  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 6  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 7  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 8  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
# 9  docker.io/library/memory-stress:latest  192.168.242.134:10250  kubelet
#
#         metrics_path                                               name  \
# 0  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 1  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 2  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 3  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 4  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 5  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 6  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 7  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 8  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
# 9  /metrics/cadvisor  0300a3ee943145f38e9ce433dc486332bc89218d2edc7b...
#
#             namespace node                                 pod  \
# 0  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 1  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 2  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 3  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 4  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 5  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 6  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 7  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 8  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
# 9  memory-stress-test  x86  memory-stress-app-664c7bc4ff-ptfl6
#
#                          service failure_type scope interface device
# 0  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 1  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 2  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 3  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 4  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 5  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 6  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 7  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 8  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 9  kube-prometheus-stack-kubelet          NaN   NaN       NaN    NaN
# 📊 Tipos de dados:
# timestamp       datetime64[ns]
# metric_name             object
# value                  float64
# __name__                object
# container               object
# cpu                     object
# endpoint                object
# id                      object
# image                   object
# instance                object
# job                     object
# metrics_path            object
# name                    object
# namespace               object
# node                    object
# pod                     object
# service                 object
# failure_type            object
# scope                   object
# interface               object
# device                  object
# dtype: object
# 📈 Estatísticas dos valores:
# count    5.141000e+03
# mean     1.978193e+08
# std      4.867007e+08
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.110000e+02
# 75%      1.015808e+06
# max      1.759393e+09
# Name: value, dtype: float64
# ✅ Dataset salvo em CSV: cadvisor_metrics_dataset.csv
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 266
#     264 # Parquet (mais eficiente)
#     265 parquet_file = 'cadvisor_metrics_dataset.parquet'
# --> 266 df.to_parquet(parquet_file, index=False)
#     267 print(f"✅ Dataset salvo em Parquet: {parquet_file}")
#     269 # Excel (opcional - pode ser lento para datasets grandes)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:2889, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2802 """
#    2803 Write a DataFrame to the binary parquet format.
#    2804
#    (...)
#    2885 >>> content = f.read()
#    2886 """
#    2887 from pandas.io.parquet import to_parquet
# -> 2889 return to_parquet(
#    2890     self,
#    2891     path,
#    2892     engine,
#    2893     compression=compression,
#    2894     index=index,
#    2895     partition_cols=partition_cols,
#    2896     storage_options=storage_options,
#    2897     **kwargs,
#    2898 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parquet.py:407, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     405 if isinstance(partition_cols, str):
#     406     partition_cols = [partition_cols]
# --> 407 impl = get_engine(engine)
#     409 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     411 impl.write(
#     412     df,
#     413     path_or_buf,
#    (...)
#     418     **kwargs,
#     419 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parquet.py:60, in get_engine(engine)
#      57         except ImportError as err:
#      58             error_msgs += "\n - " + str(err)
# ---> 60     raise ImportError(
#      61         "Unable to find a usable engine; "
#      62         "tried using: 'pyarrow', 'fastparquet'.\n"
#      63         "A suitable version of "
#      64         "pyarrow or fastparquet is required for parquet "
#      65         "support.\n"
#      66         "Trying to import the above resulted in these errors:"
#      67         f"{error_msgs}"
#      68     )
#      70 if engine == "pyarrow":
#      71     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.
